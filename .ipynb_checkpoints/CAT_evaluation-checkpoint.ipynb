# %%
import xarray as xr
import glob
import intake
import numpy as np
import seaborn as sns
from scipy import stats


# import warnings
# warnings.filterwarnings('ignore', category=UserWarning)

# %%
from plotting_maps.acs_plotting_maps import plot_acs_hazard_multi, plot_acs_hazard, plot_data, cmap_dict, regions_dict
from matplotlib import colors, cm
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

from dask.diagnostics import ProgressBar
# ProgressBar().register()

import dask
from dask.distributed import Client
client = Client(threads_per_worker=1, n_workers=4)
client
# Out:
# <Client: 'tcp://127.0.0.1:43983' processes=4 threads=4, memory=63.00 GiB>
# 2025-09-18 17:23:02,540 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42009' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'quantile-fcbe0530-8234-4e50-82f3-4310a9fdcae7', 'quantile-6ddebbe1-5bcf-4023-89cc-5727eb11c814'} (stimulus_id='handle-worker-cleanup-1758180182.5343924')
# 2025-09-18 17:23:05,266 - distributed.nanny - WARNING - Restarting worker
# 2025-09-18 17:23:05,279 - distributed.nanny - WARNING - Restarting worker
# 2025-09-18 17:23:05,308 - distributed.nanny - WARNING - Restarting worker
# 2025-09-18 17:23:05,535 - distributed.nanny - WARNING - Restarting worker
# 2025-09-18 17:23:05,537 - distributed.nanny - WARNING - Restarting worker
# 2025-09-18 17:23:05,543 - distributed.nanny - WARNING - Restarting worker
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-16168' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:2391> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py", line 2400, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-16173' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:2391> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py", line 2400, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-16174' coro=<Client._gather.<locals>.wait() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:2391> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py", line 2400, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
cat_name = "barpa"
col = intake.open_esm_datastore(f"/g/data/lp01/collections/py3.9_dev/nci-{cat_name}.json")

# Edit this cell
var_list = ["ua200", "ua250", "ua300", "va200", "va250", "va300",]
table_id = "6hr"
scenarios = ["historical", "evaluation"]

# change this query to select a subset of the data you are interested in
query = dict(variable_id = var_list[0],
             table_id = table_id,
             experiment_id = scenarios,
            )

cat = col.search(**query)
cat.unique()
# Out:
# activity_id                                                    [BARPA-R]
# institution_id                                                     [BOM]
# version                                                      [v20231001]
# variable_id                                                      [ua200]
# table_id                                                           [6hr]
# source_id              [ACCESS-CM2, ACCESS-ESM1-5, CESM2, CMCC-ESM2, ...
# experiment_id                                   [historical, evaluation]
# member_id                      [r4i1p1f1, r6i1p1f1, r11i1p1f1, r1i1p1f1]
# grid_label                                                      [AUS-15]
# time_range             [196001-196012, 196101-196112, 196201-196212, ...
# path                   [/g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM...
# derived_variable_id                                                   []
# dtype: object

# %%
cat_df_max = cat.df.groupby(["variable_id", "experiment_id", "source_id", "member_id"]).max().reset_index()
cat_df_max["index"] = cat_df_max.experiment_id + "_" + cat_df_max.source_id + "_" + cat_df_max.member_id
cat_df_max = cat_df_max.set_index("index")
cat_df_max
# Out:
#                                   variable_id experiment_id      source_id  \
# index
# evaluation_ERA5_r1i1p1f1                ua200    evaluation           ERA5
# historical_ACCESS-CM2_r4i1p1f1          ua200    historical     ACCESS-CM2
# historical_ACCESS-ESM1-5_r6i1p1f1       ua200    historical  ACCESS-ESM1-5
# historical_CESM2_r11i1p1f1              ua200    historical          CESM2
# historical_CMCC-ESM2_r1i1p1f1           ua200    historical      CMCC-ESM2
# historical_EC-Earth3_r1i1p1f1           ua200    historical      EC-Earth3
# historical_MPI-ESM1-2-HR_r1i1p1f1       ua200    historical  MPI-ESM1-2-HR
# historical_NorESM2-MM_r1i1p1f1          ua200    historical     NorESM2-MM
#
#                                    member_id activity_id institution_id  \
# index
# evaluation_ERA5_r1i1p1f1            r1i1p1f1     BARPA-R            BOM
# historical_ACCESS-CM2_r4i1p1f1      r4i1p1f1     BARPA-R            BOM
# historical_ACCESS-ESM1-5_r6i1p1f1   r6i1p1f1     BARPA-R            BOM
# historical_CESM2_r11i1p1f1         r11i1p1f1     BARPA-R            BOM
# historical_CMCC-ESM2_r1i1p1f1       r1i1p1f1     BARPA-R            BOM
# historical_EC-Earth3_r1i1p1f1       r1i1p1f1     BARPA-R            BOM
# historical_MPI-ESM1-2-HR_r1i1p1f1   r1i1p1f1     BARPA-R            BOM
# historical_NorESM2-MM_r1i1p1f1      r1i1p1f1     BARPA-R            BOM
#
#                                      version table_id grid_label  \
# index
# evaluation_ERA5_r1i1p1f1           v20231001      6hr     AUS-15
# historical_ACCESS-CM2_r4i1p1f1     v20231001      6hr     AUS-15
# historical_ACCESS-ESM1-5_r6i1p1f1  v20231001      6hr     AUS-15
# historical_CESM2_r11i1p1f1         v20231001      6hr     AUS-15
# historical_CMCC-ESM2_r1i1p1f1      v20231001      6hr     AUS-15
# historical_EC-Earth3_r1i1p1f1      v20231001      6hr     AUS-15
# historical_MPI-ESM1-2-HR_r1i1p1f1  v20231001      6hr     AUS-15
# historical_NorESM2-MM_r1i1p1f1     v20231001      6hr     AUS-15
#
#                                       time_range  \
# index
# evaluation_ERA5_r1i1p1f1           202001-202012
# historical_ACCESS-CM2_r4i1p1f1     201401-201412
# historical_ACCESS-ESM1-5_r6i1p1f1  201401-201412
# historical_CESM2_r11i1p1f1         201401-201412
# historical_CMCC-ESM2_r1i1p1f1      201401-201412
# historical_EC-Earth3_r1i1p1f1      201401-201412
# historical_MPI-ESM1-2-HR_r1i1p1f1  201401-201412
# historical_NorESM2-MM_r1i1p1f1     201401-201412
#
#                                                                                 path
# index
# evaluation_ERA5_r1i1p1f1           /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_ACCESS-CM2_r4i1p1f1     /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_ACCESS-ESM1-5_r6i1p1f1  /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_CESM2_r11i1p1f1         /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_CMCC-ESM2_r1i1p1f1      /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_EC-Earth3_r1i1p1f1      /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_MPI-ESM1-2-HR_r1i1p1f1  /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...
# historical_NorESM2-MM_r1i1p1f1     /g/data/py18/BARPA/output/CMIP6/DD/AUS-15/BOM/...

# %%
# indices for evaluation, historical and future groups. These will share time ranges
i_evaluation = cat_df_max.loc[cat_df_max["experiment_id"].isin(["evaluation"])].index
i_historical = cat_df_max.loc[cat_df_max["experiment_id"].isin(["historical"])].index

# %%
list_evaluation = ['evaluation_ERA5_r1i1p1f1']

list_historical = ['historical_ACCESS-CM2_r4i1p1f1', 
                   'historical_ACCESS-ESM1-5_r6i1p1f1',
                   'historical_CESM2_r11i1p1f1', 
                   'historical_CMCC-ESM2_r1i1p1f1',
                   'historical_EC-Earth3_r1i1p1f1',
                   'historical_MPI-ESM1-2-HR_r1i1p1f1',
                   'historical_NorESM2-MM_r1i1p1f1',
                  ]

# %%
def plot_model_obs_kde(model, obs, 
                       title = "", xlabel = "", var_name = "tas", ax = None):
    """Takes models and observation anomalies and calculated the pdfs using a kernel density function
    A two sided KS test is conducted to indicate if the distributions are statistically different"""
     
    sns.kdeplot(model, color="r", linestyle = "-", bw_adjust=1.5, ax=ax, label = "model")
    sns.kdeplot(obs, color="k", linestyle = "--", ax=ax, label = "obs").set(title = title)
    
    try:
        ax.legend(["model", "obs"])
        ax.set_xlabel(xlabel)    
    except:
        plt.legend(["model", "obs"])
        plt.xlabel(xlabel)
        
    # Calculate the pvalue for the two-sample K-S test.
    # If p is large, then the two samples are statistically indistinguishable
    _, p = stats.ks_2samp(model, obs)
    print(f"p = {p}")
            
    if p > 0.05:
        # cannot reject null hypothesis
        h="0"
    elif p <= 0.05:
        # reject null hypothesis
        h="1"
    
    try: # if a figure is already defined
        ax.text(x = 0.8, y= 0.7, s = f"h = {h}\np = {p:.3f}", transform=ax.transAxes)
    except:  
        ax = plt.sca()
        plt.text(x = 0.8, y= 0.7, s = f"h = {h}\np = {p:.3f}", transform=ax.transAxes)
    return ax, h

# %%
hist_eval = xr.open_dataset("/scratch/v46/gt3409/historical_evaluation.nc")

# %%
hist_eval
# Out:
# <xarray.Dataset> Size: 217MB
# Dimensions:    (run: 8, time: 10, lat: 436, lon: 777)
# Coordinates:
#   * lon        (lon) float64 6kB 88.04 88.19 88.34 88.5 ... 207.6 207.8 207.9
#   * lat        (lat) float64 3kB -53.58 -53.42 -53.27 ... 13.32 13.48 13.63
#     pressure   int64 8B ...
#   * run        (run) <U33 1kB 'evaluation_ERA5_r1i1p1f1' ... 'historical_NorE...
#   * time       (time) int64 80B 1980 1981 1982 1983 1984 ... 1986 1987 1988 1989
# Data variables:
#     windspeed  (run, time, lat, lon) float64 217MB ...

# %%
(hist_eval.lon.size ) * (hist_eval.lat.size )
# Out:
# 338772

# %%
(hist_eval.lon.size - 2*13 ) * (hist_eval.lat.size - 2*13 )
# Out:
# 307910

# %%
307910/338772
# Out:
# 0.9089003813774456

# %%
era5 = hist_eval.sel(run='evaluation_ERA5_r1i1p1f1')["windspeed"].mean("time")

# %%
(-53.58+13*0.1545 , 13.63-13*0.1545)
# Out:
# (-51.5715, 11.621500000000001)

# %%
(88.04+13*0.1545 , 207.9-13*0.1545)
# Out:
# (90.0485, 205.8915)

# %%
fig, axs = plot_acs_hazard_multi(nrows=4, 
                      ncols=2, 
                      ds_list=[hist_eval.sel(run=run)["windspeed"].mean("time") 
                               for run in list_evaluation+ list_historical],
                      mask_not_australia=False,
                      ticks=np.arange(0, 0.08, 0.005),
                      tick_interval=2,
                      cbar_extend="max",
                      cbar_label="frequency of exceeding p99 windspeed",
                      figsize=(8,10),
                      title="frequency of exceeding p99 windspeed 250hPa",
                      subplot_titles=[run for run in list_evaluation+ list_historical],
                      xlim=(88.04 , 207.9),
                      ylim=(-53.58 , 13.63),
                      coastlines=True,
                      projection=ccrs.PlateCarree(130),
                      cmap=cmap_dict["ipcc_wind_seq"],
                      watermark="",
                      show_copyright=False,
                     );

# %%
plot_acs_hazard_multi(nrows=4, 
                      ncols=2, 
                      ds_list=[(hist_eval.sel(run=run)["windspeed"].mean("time") - era5) 
                               for run in list_evaluation+ list_historical],
                      mask_not_australia=False,
                      ticks=np.arange(-0.05, 0.051, 0.005),
                      tick_interval=2,
                      cbar_extend="both",
                      title="Difference in frequency of exceeding p99 windspeed from ERA5",
                      figsize=(8,10),
                      cbar_label="frequency of exceeding p99 windspeed 250hPa",
                      subplot_titles=[run for run in list_evaluation+ list_historical],
                      xlim=(88.04 , 207.9),
                      ylim=(-53.58 , 13.63),
                      coastlines=True,
                      projection=ccrs.PlateCarree(130),
                      # cmap=cmap_dict["ipcc_wind_div"],
                      cmap=cmap_dict["anom"],
                      watermark="",
                      show_copyright=False,
                     );

# %%
# %%time
for run in list_evaluation+ list_historical:
    plt.figure()
    ax = plt.subplot(projection=ccrs.PlateCarree(130))
    hist_eval.sel(run=run)["windspeed"].mean("time").plot(vmax=0.08, transform=ccrs.PlateCarree(), ax=ax)
    plt.title(run)
    ax.yaxis.set_visible(True)
    ax.grid()
    ax.coastlines()
# Out:
# CPU times: user 1.44 s, sys: 156 ms, total: 1.6 s
# Wall time: 1.43 s

# %%
for run in list_historical:
    plt.figure()
    ax = plt.subplot(projection=ccrs.PlateCarree(130))
    (hist_eval.sel(run=run)["windspeed"].mean("time") - era5).plot(cmap="RdBu_r", vmin=-0.05, vmax=0.05, transform=ccrs.PlateCarree(), ax=ax)
    plt.title(run)
    ax.yaxis.set_visible(True)
    ax.grid()
    ax.coastlines()

# %%
# %%time
turbulence_index = "windspeed"

quantiles_models ={}
for run in list_evaluation + list_historical:
    experiment_id, source_id, member_id = run.split("_")
    print(run)

    for year in [1980]:#np.arange(1980,1990+1):
        # opening
        file = f"/scratch/v46/gt3409/TMP_windspeed/TMP_{turbulence_index}_AUS-15_{source_id}_{experiment_id}_{member_id}_BOM_BARPA-R_v1-r1_6hr_{year}.nc"
        ds_model = xr.open_dataset(file, ).assign_coords({"run":run, "year":year})
    
        quantiles_models[f"{run}"] = dask.delayed(ds_model.quantile)(np.arange(0, 1, 0.01),)

results = dask.compute(quantiles_models,)
results
# Out:
# evaluation_ERA5_r1i1p1f1
# historical_ACCESS-CM2_r4i1p1f1
# historical_ACCESS-ESM1-5_r6i1p1f1
# historical_CESM2_r11i1p1f1
# historical_CMCC-ESM2_r1i1p1f1
# historical_EC-Earth3_r1i1p1f1
# historical_MPI-ESM1-2-HR_r1i1p1f1
# historical_NorESM2-MM_r1i1p1f1
# 2025-09-18 17:39:41,926 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.19 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:39:51,933 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.22 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:00,624 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.24 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:04,324 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.09 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:10,721 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.25 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:14,431 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.25 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:15,225 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.19 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:19,130 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 12.71 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:25,323 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.92 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:34,523 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.22 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:35,434 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.92 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:38,223 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 11.23 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:38,789 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 12.74 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:44,622 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 15.75 GiB
# 2025-09-18 17:40:45,523 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 11.23 GiB -- Worker memory limit: 15.75 GiB
# CPU times: user 21 s, sys: 5.08 s, total: 26.1 s
# Wall time: 2min 6s
# 2025-09-18 17:40:54,520 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 11.25 GiB -- Worker memory limit: 15.75 GiB
# ({'evaluation_ERA5_r1i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.23 1.754 ... 59.15 62.88 68.46,
#   'historical_ACCESS-CM2_r4i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.246 1.774 ... 60.16 63.84 69.17,
#   'historical_ACCESS-ESM1-5_r6i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.223 1.743 ... 58.76 62.34 67.84,
#   'historical_CESM2_r11i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.372 1.958 ... 60.11 64.11 70.13,
#   'historical_CMCC-ESM2_r1i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.332 1.898 ... 60.06 63.79 69.6,
#   'historical_EC-Earth3_r1i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.293 1.844 ... 60.11 63.93 69.6,
#   'historical_MPI-ESM1-2-HR_r1i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.281 1.826 ... 63.06 67.1 73.24,
#   'historical_NorESM2-MM_r1i1p1f1': <xarray.Dataset> Size: 2kB
#   Dimensions:    (quantile: 100)
#   Coordinates:
#     * quantile   (quantile) float64 800B 0.0 0.01 0.02 0.03 ... 0.97 0.98 0.99
#   Data variables:
#       windspeed  (quantile) float64 800B 0.0 1.367 1.951 ... 58.7 62.51 68.33},)

# %%
quantiles_models = xr.concat([results[0][run] for run in list_evaluation + list_historical], 
                             dim="run").assign_coords({"run": list_evaluation + list_historical})
quantiles_models

# %%
# %%time
turbulence_index = "windspeed"
fig, axs = plt.subplots(4,2, figsize=(8,12), sharex=True, sharey=True)
i=0
for run in list_historical:
    print(run)
    # if p-value is less than 0.05 then reject that model
    var = "windspeed"

    plot_model_obs_kde(quantiles_models[var].sel({"run":run}),
                       quantiles_models[var].sel({"run":list_evaluation[0]}),
                       title=f"{run}",
                       xlabel = f"ANN {var}",
                       ax = axs[i//2, i%2])
    plt.xlim(0,100)
    i+=1
# Out:
# historical_ACCESS-CM2_r4i1p1f1
# p = 1.0
# historical_ACCESS-ESM1-5_r6i1p1f1
# p = 1.0
# historical_CESM2_r11i1p1f1
# p = 0.999998821968263
# historical_CMCC-ESM2_r1i1p1f1
# p = 0.9999999999999999
# historical_EC-Earth3_r1i1p1f1
# p = 0.9999999999962054
# historical_MPI-ESM1-2-HR_r1i1p1f1
# p = 0.9999999999962054
# historical_NorESM2-MM_r1i1p1f1
# p = 0.999998821968263
# CPU times: user 357 ms, sys: 31.6 ms, total: 389 ms
# Wall time: 351 ms

# %%
# %%time
turbulence_index = "windspeed"
for run in i_historical:
    experiment_id, source_id, member_id = run.split("_")
    print(run)

    plt.figure()
    quantiles_models[var].sel({"run":list_evaluation[0]}).plot(color="k",linestyle="--")
    quantiles_models[var].sel({"run":run}).plot(color="r")
    plt.show
# Out:
# historical_ACCESS-CM2_r4i1p1f1
# historical_ACCESS-ESM1-5_r6i1p1f1
# historical_CESM2_r11i1p1f1
# historical_CMCC-ESM2_r1i1p1f1
# historical_EC-Earth3_r1i1p1f1
# historical_MPI-ESM1-2-HR_r1i1p1f1
# historical_NorESM2-MM_r1i1p1f1
# CPU times: user 115 ms, sys: 3.85 ms, total: 119 ms
# Wall time: 108 ms

# %%
# %%time
turbulence_index = "windspeed"
p99 =73.46444525842983
threshold = p99

delayed_results =[]
for run in list_evaluation + list_historical:
    experiment_id, source_id, member_id = run.split("_")
    print(run)

    def _preprocess(ds, threshold=p99):
        return (ds.chunk({"time":-1, "lat":200, "lon":160})>threshold).mean(dim=["time"])

    time_range = np.arange(1980, 1989+1)
    filelist = [ f"/scratch/v46/gt3409/TMP_{turbulence_index}/TMP_{turbulence_index}_AUS-15_{source_id}_{experiment_id}_{member_id}_BOM_BARPA-R_v1-r1_6hr_{year}.nc" 
                for year in time_range]
    
    ds = xr.open_mfdataset(filelist, use_cftime=True, preprocess=_preprocess, combine="nested", concat_dim="time").assign_coords({"run":run, "time":time_range})
    delayed_results.append(ds)

results = dask.compute(delayed_results)
results
# Out:
# evaluation_ERA5_r1i1p1f1
# KeyboardInterrupt

# %%
historical_eval = xr.concat(results[0], dim="run")
historical_eval

# %%
historical_eval.to_netcdf("/scratch/v46/gt3409/historical_evaluation.nc")

# %%
historical_eval = xr.open_dataset("/scratch/v46/gt3409/historical_evaluation.nc")
historical_eval
# Out:
# <xarray.Dataset> Size: 217MB
# Dimensions:    (run: 8, time: 10, lat: 436, lon: 777)
# Coordinates:
#   * lon        (lon) float64 6kB 88.04 88.19 88.34 88.5 ... 207.6 207.8 207.9
#   * lat        (lat) float64 3kB -53.58 -53.42 -53.27 ... 13.32 13.48 13.63
#     pressure   int64 8B ...
#   * run        (run) <U33 1kB 'evaluation_ERA5_r1i1p1f1' ... 'historical_NorE...
#   * time       (time) int64 80B 1980 1981 1982 1983 1984 ... 1986 1987 1988 1989
# Data variables:
#     windspeed  (run, time, lat, lon) float64 217MB ...

# %%
# %%time
ds = ds.compute()
ds

# %%
ds["windspeed"].mean("time").plot()

# %%
ssp_colors = {"evaluation":"k",
              "historical":"grey",
              }
